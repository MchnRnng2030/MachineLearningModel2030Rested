# %%
# ======================================================
# STEP 0: 입력 파일 존재 여부 확인
# ======================================================

import os

POLICY_PATH = "../results/oxju/policy_matrix_final.csv"
LRRF_PATH   = "../results/hyun/employment_predictions.csv"

print("=" * 70)
print("🔍 STEP 0: 입력 파일 확인")
print("=" * 70)

missing = False

if not os.path.exists(POLICY_PATH):
    print(f"❌ 정책 파일 없음: {POLICY_PATH}")
    missing = True
else:
    print(f"✅ 정책 파일 확인: {POLICY_PATH}")

if not os.path.exists(LRRF_PATH):
    print(f"❌ LR/RF 파일 없음: {LRRF_PATH}")
    missing = True
else:
    print(f"✅ LR/RF 파일 확인: {LRRF_PATH}")

if missing:
    raise FileNotFoundError("입력 파일 누락 → 이전 노트북 실행 필요")

print("\n🎉 STEP 0 통과")
# Out:
# ...
# 🔍 STEP 0: 입력 파일 확인
# ...
# ✅ 정책 파일 확인: ../results/oxju/policy_matrix_final.csv
# ✅ LR/RF 파일 확인: ../results/hyun/employment_predictions.csv
#
# 🎉 STEP 0 통과
