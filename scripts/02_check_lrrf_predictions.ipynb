# %%
# ======================================================
# STEP 2: LR/RF 예측 결과 점검
# ======================================================

import pandas as pd

LRRF_PATH = "../results/hyun/employment_predictions.csv"

print("=" * 70)
print("🔍 STEP 2: LR/RF 예측 결과 점검")
print("=" * 70)

df = pd.read_csv(LRRF_PATH)

import os
print(os.path.getsize(LRRF_PATH) / 1024 / 1024, "MB")

print("📊 shape:", df.shape)
print("\n📌 columns:")
for c in df.columns:
    print(" -", c)

REQUIRED_COLS = ["p_employ_lr", "p_employ_rf"]
missing = [c for c in REQUIRED_COLS if c not in df.columns]

if missing:
    raise ValueError(f"❌ LR/RF 예측 컬럼 누락: {missing}")

print("\n✅ LR/RF 예측 결과 정상")
# Out:
# ...
# 🔍 STEP 2: LR/RF 예측 결과 점검
# ...
# 3.5839385986328125 MB
# 📊 shape: (61326, 10)
#
# 📌 columns:
#  - 조사연도
#  - 출생연도
#  - 성별코드
#  - 만연령
#  - 교육정도_학력구분코드
#  - 혼인상태코드
#  - 직업훈련경험
#  - 쉬었음
#  - p_employ_lr
#  - p_employ_rf
#
# ✅ LR/RF 예측 결과 정상
